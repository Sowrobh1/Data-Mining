# %% [markdown]
# <a href="https://colab.research.google.com/github/Sowrobh1/Data-Mining/blob/main/heart_disease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.frequent_patterns import apriori, association_rules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Heart_disease/heart_disease.csv')
df
# Out:
#         age  sex  cp trestbps    chol  fbs  restecg thalach  exang oldpeak  \
# 0      high    1   3     high  medium    1        0  medium      0    high
# 1       low    1   2   medium  medium    0        1    high      0    high
# 2       low    0   1   medium     low    0        0    high      0    high
# 3    medium    1   1      low  medium    0        1    high      0  medium
# 4    medium    0   0      low    high    0        1    high      1  medium
# ..      ...  ...  ..      ...     ...  ...      ...     ...    ...     ...
# 298  medium    0   0     high  medium    0        1     low      1  medium
# 299     low    1   3      low    high    0        1     low      0  medium
# 300    high    1   0     high     low    1        1     low      0    high
# 301  medium    1   0   medium     low    0        1     low      1  medium
# 302  medium    0   1   medium  medium    0        0    high      0     low
#
#      slope  ca  thal  target
# 0        0   0     1       1
# ...

# %%
df_encoded = pd.get_dummies(df, columns=df.columns)
df_encoded
# Out:
#      age_high  age_low  age_medium  sex_0  sex_1   cp_0   cp_1   cp_2   cp_3  \
# 0        True    False       False  False   True  False  False  False   True
# 1       False     True       False  False   True  False  False   True  False
# 2       False     True       False   True  False  False   True  False  False
# 3       False    False        True  False   True  False   True  False  False
# 4       False    False        True   True  False   True  False  False  False
# ..        ...      ...         ...    ...    ...    ...    ...    ...    ...
# 298     False    False        True   True  False   True  False  False  False
# 299     False     True       False  False   True  False  False  False   True
# 300      True    False       False  False   True   True  False  False  False
# 301     False    False        True  False   True   True  False  False  False
# 302     False    False        True   True  False  False   True  False  False
#
# ...

# %%
frequent_itemsets = apriori(df_encoded, min_support=0.3, use_colnames=True)
print(frequent_itemsets)
# Out:
#      support                            itemsets
# 0   0.343234                          (age_high)
# 1   0.313531                           (age_low)
# 2   0.343234                        (age_medium)
# 3   0.316832                             (sex_0)
# 4   0.683168                             (sex_1)
# ..       ...                                 ...
# 88  0.376238         (target_1, thal_2, exang_0)
# 89  0.336634            (target_1, thal_2, ca_0)
# 90  0.323432    (target_1, fbs_0, exang_0, ca_0)
# 91  0.330033  (target_1, thal_2, exang_0, fbs_0)
# 92  0.303630     (target_1, thal_2, fbs_0, ca_0)
#
# [93 rows x 2 columns]

# %%
discovered_rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)
discovered_rules.head()
# Out:
#    antecedents consequents  antecedent support  consequent support   support  \
# 0       (cp_0)     (sex_1)            0.471947            0.683168  0.343234
# 1      (sex_1)     (fbs_0)            0.683168            0.851485  0.574257
# 2  (restecg_0)     (sex_1)            0.485149            0.683168  0.339934
# 3     (thal_3)     (sex_1)            0.386139            0.683168  0.336634
# 4   (target_0)     (sex_1)            0.455446            0.683168  0.376238
#
#    confidence      lift  representativity  leverage  conviction  \
# 0    0.727273  1.064559               1.0  0.020815    1.161716
# 1    0.840580  0.987192               1.0 -0.007450    0.931593
# 2    0.700680  1.025633               1.0  0.008496    1.058506
# 3    0.871795  1.276106               1.0  0.072836    2.471287
# 4    0.826087  1.209200               1.0  0.065092    1.821782
#
#    zhangs_metric   jaccard  certainty  kulczynski
# 0       0.114844  0.422764   0.139205    0.614844
# ...

# %%
top_10 = discovered_rules.sort_values(by=["confidence", "lift"], ascending=False).head(10)
top_10[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
# Out:
#                  antecedents consequents   support  confidence      lift
# 8             (trestbps_low)     (fbs_0)  0.313531    0.940594  1.104651
# 55            (thal_2, ca_0)     (fbs_0)  0.343234    0.912281  1.071399
# 93  (target_1, thal_2, ca_0)     (fbs_0)  0.303630    0.901961  1.059280
# 77            (thal_2, ca_0)  (target_1)  0.336634    0.894737  1.643062
# 45           (exang_0, ca_0)     (fbs_0)  0.386139    0.893130  1.048908
# 62         (thal_2, slope_2)   (exang_0)  0.300330    0.892157  1.325115
# 15                    (ca_0)     (fbs_0)  0.511551    0.885714  1.040199
# 95     (thal_2, ca_0, fbs_0)  (target_1)  0.303630    0.884615  1.624476
# 57          (target_1, ca_0)     (fbs_0)  0.379538    0.884615  1.038909
# 16                  (thal_2)     (fbs_0)  0.481848    0.879518  1.032922

# %%
highlighted_rule = top_10.iloc[0]
print("Rule:", highlighted_rule['antecedents'], "→", highlighted_rule['consequents'])
print("Support:", round(highlighted_rule['support'], 2))
print("Confidence:", round(highlighted_rule['confidence'], 2))
print("Lift:", round(highlighted_rule['lift'], 2))
# Out:
# Rule: frozenset({'trestbps_low'}) → frozenset({'fbs_0'})
# Support: 0.31
# Confidence: 0.94
# Lift: 1.1
